# %%
import pandas as pd
import pprint

# %%
csv_file = 'data_files/malaria_data.csv'
malaria_df = pd.read_csv(csv_file)

# %%
malaria_df
# Out:
#      Year  Argentina   Belize   Bolivia     Brazil   Colombia  Costa Rica  \
# 0    2000      440.0   1486.0   31469.0   613241.0   144432.0      1879.0
# 1    2001      215.0   1162.0   15765.0   388303.0   231233.0      1363.0
# 2    2002      125.0   1134.0   14276.0   348259.0   204916.0      1021.0
# 3    2003      124.0   1084.0   20343.0   408886.0   180956.0       718.0
# 4    2004      116.0   1066.0   14910.0   465004.0   142241.0      1289.0
# 5    2005      252.0   1549.0   21442.0   606067.0   121629.0      3541.0
# 6    2006      212.0    844.0   19725.0   549469.0   120096.0      2903.0
# 7    2007      355.0    845.0   14610.0   458652.0   128462.0      1223.0
# 8    2008      106.0    540.0    9748.0   315746.0    80559.0       966.0
# 9    2009      136.0    512.0   19486.0   309316.0   158694.0       524.0
# 10   2010       72.0    300.0   27538.0   669335.0   235300.0       228.0
# 11   2011       36.0    158.0   14286.0   534292.0   128745.0        34.0
# ...

# %%
malaria_df.columns[0]
# Out:
# 'Year'

# %%
geoJSON = {
    "type": "Feature Collection",
    "features": [
        {
            "type": "Feature",
            "geometry": {
                "name": malaria_df.columns[1],
                "coordinates": ['lat','long']
            },
            "properties": {
                "incidents": malaria_df[malaria_df.columns[1]]
            }
        }
    ]
}

# %%
geoJSON
# Out:
# {'type': 'Feature Collection', 'features': [{'type': 'Feature', 'geometry': {'name': 'Argentina', 'coordinates': ['lat', 'long']}, 'properties': {'incidents': 0      440.0
# 1      215.0
# 2      125.0
# 3      124.0
# 4      116.0
# 5      252.0
# 6      212.0
# 7      355.0
# 8      106.0
# 9      136.0
# 10      72.0
# 11      36.0
# 12       8.0
# 13       8.0
# 14       8.0
# 15       2.0
# 16       2.0
# 17      33.0
# 18    2250.0
# Name: Argentina, dtype: float64}}]}
