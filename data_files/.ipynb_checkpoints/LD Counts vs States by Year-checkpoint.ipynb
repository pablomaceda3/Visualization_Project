# %%
import pandas as pd

# %%
csv = "US Intercensal Estimates 2000-2018.csv"
census_df = pd.read_csv(csv)
census_df
# Out:
#                              2000         2001         2002         2003  \
# United States         282,162,411  284,968,955  287,625,193  290,107,933
# Alabama                 4,452,173    4,467,634    4,480,089    4,503,491
# Alaska                    627,963      633,714      642,337      648,414
# Arizona                 5,160,586    5,273,477    5,396,255    5,510,364
# Arkansas                2,678,588    2,691,571    2,705,927    2,724,816
# California             33,987,977   34,479,458   34,871,843   35,253,159
# Colorado                4,326,921    4,425,687    4,490,406    4,528,732
# Connecticut             3,411,777    3,432,835    3,458,749    3,484,336
# Delaware                  786,373      795,699      806,169      818,003
# District of Columbia      572,046      574,504      573,158      568,502
# Florida                16,047,515   16,356,966   16,689,370   17,004,085
# Georgia                 8,227,303    8,377,038    8,508,256    8,622,793
# ...

# %%
#census_df['2000'].str.replace(",","")

# %%
census_df['Population Growth % 2000-2006'] = (census_df['2006'].str.replace(",","").astype(int)) - census_df['2000'].str.replace(",","").astype(int)) / census_df['2000'].str.replace(",","").astype(int) * 100
# census_df['Population Growth % 2006-2012'] = (census_df['2012'] - census_df['2006'].str.replace(",","").astype(int)) / census_df['2006'].str.replace(",","").astype(int) * 100
# census_df['Population Growth % 2012-2017'] = (census_df['2017'] - census_df['2012'] / census_df['2012'] * 100)
# Out:
#   File "<ipython-input-6-3c099e89de0f>", line 1
#     census_df['Population Growth % 2000-2006'] = (census_df['2006'].str.replace(",","").astype(int)) - census_df['2000'].str.replace(",","").astype(int)) / census_df['2000'].str.replace(",","").astype(int) * 100
#                                                                                                                                                         ^
# SyntaxError: invalid syntax
